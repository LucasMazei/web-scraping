# %%
from bs4 import BeautifulSoup as soup  # HTML data structure
import urllib  # Web client
from IPython.display import clear_output # Função para limpar a tela
import webbrowser # biblioteca para abrir um link

# %%
page_url = "https://www.sonoticias.com.br/" # página que estaremos fazendo o Web Scraping

# Cabeçalho do dosso request (pedido)
headers = {
    "Host": "www.sonoticias.com.br",
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64; rv:76.0) Gecko/20100101 Firefox/76.0",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
}

request = urllib.request.Request(page_url, headers=headers) # faz o request 
response = urllib.request.urlopen(request) # obtem a response (resposta)
page_soup = soup(response.read(), "html.parser") # transforma a sopa de dados em uma estrutura JSON
print(page_soup.prettify()) # printa o arquivo HTML de forma legível
# Out:
# /www.sonoticias.com.br/wp-content/uploads/2020/04/policia-de-mato-grosso-recebe-mais-armamentos-vimeo-thumbnail-1024x576.jpg 1024w, https://www.sonoticias.com.br/wp-content/uploads/2020/04/policia-de-mato-grosso-recebe-mais-armamentos-vimeo-thumbnail-990x556.jpg 990w, https://www.sonoticias.com.br/wp-content/uploads/2020/04/policia-de-mato-grosso-recebe-mais-armamentos-vimeo-thumbnail-1320x742.jpg 1320w, https://www.sonoticias.com.br/wp-content/uploads/2020/04/policia-de-mato-grosso-recebe-mais-armamentos-vimeo-thumbnail-470x264.jpg 470w, https://www.sonoticias.com.br/wp-content/uploads/2020/04/policia-de-mato-grosso-recebe-mais-armamentos-vimeo-thumbnail-640x360.jpg 640w, https://www.sonoticias.com.br/wp-content/uploads/2020/04/policia-de-mato-grosso-recebe-mais-armamentos-vimeo-thumbnail-215x120.jpg 215w" width="414"/>
#             <span class="herald-format-icon">
#              <i class="fa fa-play">
#              </i>
#             </span>
#            </a>
#           </div>
#           <div class="entry-header">
#            <span class="meta-category meta-small">
#             <a class="herald-cat-70" href="https://www.sonoticias.com.br/vimeo-videos/videos/">
#              Vídeos
#             </a>
#            </span>
#            <h2 class="entry-title h5">
#             <a href="https://www.sonoticias.com.br/vimeo-video/policia-de-mato-grosso-recebe-mais-armamentos/">
#              Polícia de Mato Grosso recebe mais armamentos
#             </a>
#            </h2>
#           </div>
#          </article>
#         </div>
#        </div>
#        <div class="herald-module col-lg-12 col-md-12 col-sm-12" data-col="12" id="herald-module-2-10">
#         <div class="herald-mod-wrap">
#          <div class="herald-mod-head">
#           <div class="herald-mod-title">
#            <h2 class="h6 herald-mod-h herald-color">
#             Mais lidas
#            </h2>
#           </div>
#          </div>
#         </div>
#         <div class="row herald-posts row-eq-height">
#          <article class="herald-lay-h post-718282 post type-post status-publish format-standard has-post-thumbnail hentry category-saude">
#           <div class="entry-header">
#            <span class="meta-category meta-small">
#             <a class="herald-cat-54" href="https://www.sonoticias.com.br/category/saude/">
#              Saúde
#             </a>
#            </span>
#            <h2 class="entry-title h6">
#             <a href="https://www.sonoticias.com.br/saude/sorriso-tem-40-casos-de-coronavirus-e-secretaria-constata-foco-de-contaminacao/">
#              Sorriso tem 40 casos de Coronavírus e secretaria constata foco de contaminação
#             </a>
#            </h2>
#           </div>
#          </article>
#          <article class="herald-lay-h post-718513 post type-post status-publish format-standard has-post-thumbnail hentry category-policia">
#           <div class="entry-header">
#            <span class="meta-category meta-small">
#             <a class="herald-cat-49" href="https://www.sonoticias.com.br/category/policia/">
#              Polícia
#             </a>
#            </span>
#            <h2 class="entry-title h6">
#             <a href="https://www.sonoticias.com.br/policia/envolvidos-em-crimes-trocam-tiros-com-policiais-no-nortao-e-sao-presos/">
#              Envolvidos em crimes trocam tiros com policiais no Nortão e são presos
#             </a>
#            </h2>
#           </div>
#          </article>
#          <article class="herald-lay-h post-718413 post type-post status-publish format-standard has-post-thumbnail hentry category-geral">
#           <div class="entry-header">
#            <span class="meta-category meta-small">
#             <a class="herald-cat-57" href="https://www.sonoticias.com.br/category/geral/">
#              Geral
#             </a>
#            </span>
#            <h2 class="entry-title h6">
#             <a href="https://www.sonoticias.com.br/geral/mais-de-40-empresas-sao-notificadas-em-sinop-por-pessoas-nao-usarem-mascaras/">
#              Mais de 40 empresas são notificadas em Sinop por pessoas não usarem máscaras
#             </a>
#            </h2>
#           </div>
#          </article>
#          <article class="herald-lay-h post-718237 post type-post status-publish format-standard has-post-thumbnail hentry category-politica">
#           <div class="entry-header">
#            <span class="meta-category meta-small">
#             <a class="herald-cat-48" href="https://www.sonoticias.com.br/category/politica/">
#              Política
#             </a>
#            </span>
#            <h2 class="entry-title h6">
#             <a href="https://www.sonoticias.com.br/politica/exercito-vai-atuar-em-conjunto-com-a-operacao-amazonia-arco-norte-em-mato-grosso-para-combate-de-crimes-contra-a-flora/">
#              Exército vai atuar em conjunto com operação em Mato Grosso para combater crimes ambientais
#             </a>
#            </h2>
#           </div>
#          </article>
#          <article class="herald-lay-h post-718293 post type-post status-publish format-standard has-post-thumbnail hentry category-saude">
#           <div class="entry-header">
#            <span class="meta-category meta-small">
#             <a class="herald-cat-54" href="https://www.sonoticias.com.br/category/saude/">
#              Saúde
#             </a>
#            </span>
#            <h2 class="entry-title h6">
#             <a href="https://www.sonoticias.com.br/saude/mais-duas-pessoas-morrem-em-mato-grosso-em-decorrencia-do-coronavirus-total-sobe-para-26/">
#              Mais duas pessoas morrem em Mato Grosso em decorrência do Coronavírus; total sobe para 26
#             </a>
#            </h2>
#           </div>
#          </article>
#          <article class="herald-lay-h post-718643 post type-post status-publish format-standard has-post-thumbnail hentry category-saude">
#           <div class="entry-header">
#            <span class="meta-category meta-small">
#             <a class="herald-cat-54" href="https://www.sonoticias.com.br/category/saude/">
#              Saúde
#             </a>
#            </span>
#            <h2 class="entry-title h6">
#             <a href="https://www.sonoticias.com.br/saude/mato-grosso-registra-27a-morte-por-coronavirus-e-67-novos-casos/">
#              Mato Grosso registra 27ª morte por Coronavírus e 67 novos casos
#             </a>
#            </h2>
#           </div>
#          </article>
#          <article class="herald-lay-h post-717709 post type-post status-publish format-standard has-post-thumbnail hentry category-economia">
#           <div class="entry-header">
#            <span class="meta-category meta-small">
#             <a class="herald-cat-51" href="https://www.sonoticias.com.br/category/economia/">
#              Economia
#             </a>
#            </span>
#            <h2 class="entry-title h6">
#             <a href="https://www.sonoticias.com.br/economia/crise-tambem-impacta-na-construcao-do-shopping-sinop-e-instalacao-das-lojas-inauguracao-e-postergada/">
#              Crise também impacta na construção do Shopping Sinop e instalação das lojas; inauguração é postergada
#             </a>
#            </h2>
#           </div>
#          </article>
#          <article class="herald-lay-h post-718460 post type-post status-publish format-standard has-post-thumbnail hentry category-saude">
#           <div class="entry-header">
#            <span class="meta-category meta-small">
#             <a class="herald-cat-54" href="https://www.sonoticias.com.br/category/saude/">
#              Saúde
#             </a>
#            </span>
#            <h2 class="entry-title h6">
#             <a href="https://www.sonoticias.com.br/saude/mato-grosso-tem-58-novos-casos-positivos-de-coronavirus-48-curados-e-duas-mortes/">
#              Mato Grosso tem 58 novos casos positivos de Coronavírus, 48 curados e duas mortes
#             </a>
#            </h2>
#           </div>
#          </article>
#          <article class="herald-lay-h post-718535 post type-post status-publish format-standard has-post-thumbnail hentry category-policia">
#           <div class="entry-header">
#            <span class="meta-category meta-small">
#             <a class="herald-cat-49" href="https://www.sonoticias.com.br/category/policia/">
#              Polícia
#             </a>
#            </span>
#            <h2 class="entry-title h6">
#             <a href="https://www.sonoticias.com.br/policia/preso-e-violentamente-espancado-no-presidio-ferrugem-em-sinop/">
#              Preso é violentamente espancado no presídio Ferrugem em Sinop
#             </a>
#            </h2>
#           </div>
#          </article>
#         </div>
#         <nav class="herald-pagination herald-load-more">
#          <a href="https://www.sonoticias.com.br/page/2/">
#           Mais
#          </a>
#          <div class="herald-loader">
#           <div class="spinner">
#            <div class="bounce1">
#            </div>
#            <div class="bounce2">
#            </div>
#            <div class="bounce3">
#            </div>
#           </div>
#          </div>
#         </nav>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <footer class="herald-site-footer herald-slide" id="footer">
#    <div class="footer-widgets container">
#     <div class="row">
#      <div class="col-lg-4 col-md-4 col-sm-4">
#       <div class="widget_text widget widget_custom_html" id="custom_html-3">
#        <div class="textwidget custom-html-widget">
#         <p>
#          <img alt="Só Notícias Logo" src="https://www.sonoticias.com.br/wp-content/uploads/2017/12/sonoticias_logo.png"/>
#         </p>
#         <p>
#          Só Notícias é o primeiro jornal virtual do interior de Mato Grosso, há 20 anos no ar com as melhores informações.
#         </p>
#         <p style="margin-top:25px">
#          <a class="mks_button mks_button_small squared" href="https://www.sonoticias.com.br/fale-conosco/" style="color: #FFFFFF; background-color: #0288D1" target="_blank">
#           Saiba Mais
#          </a>
#         </p>
#        </div>
#       </div>
#      </div>
#      <div class="col-lg-4 col-md-4 col-sm-4">
#       <div class="widget_text widget widget_custom_html" id="custom_html-4">
#        <h4 class="widget-title h6">
#         <span>
#          Expediente
#         </span>
#        </h4>
#        <div class="textwidget custom-html-widget">
#         <ul>
#          <li>
#           <a href="https://www.sonoticias.com.br/fale-conosco">
#            Fale Conosco
#           </a>
#          </li>
#          <li>
#           <a href="https://www.sonoticias.com.br/equipe">
#            Nossa equipe
#           </a>
#          </li>
#          <li>
#           <a href="https://www.sonoticias.com.br/anuncie">
#            Anuncie
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#      <div class="col-lg-4 col-md-4 col-sm-4">
#       <div class="widget widget_search" id="search-4">
#        <h4 class="widget-title h6">
#         <span>
#          Pesquise no site:
#         </span>
#        </h4>
#        <form action="https://www.sonoticias.com.br/" class="herald-search-form" method="get">
#         <input class="herald-search-input" name="s" placeholder="Digite aqui para pesquisar..." type="text" value=""/>
#         <button class="herald-search-submit" type="submit">
#         </button>
#        </form>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="footer-bottom">
#     <div class="container">
#      <div class="row">
#       <div class="col-lg-12">
#        <div class="hel-l herald-go-hor">
#         <div class="herald-copyright">
#          Copyright © 2000-2018. Reprodução proibida sem a autorização de Só Notícias.
#         </div>
#        </div>
#        <div class="hel-r herald-go-hor">
#         <ul class="herald-soc-nav" id="menu-herald-social-1">
#          <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-19">
#           <a href="https://www.facebook.com/SoNoticiasMT/">
#            <span class="herald-social-name">
#             Facebook
#            </span>
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-20">
#           <a href="https://twitter.com/SonoticiasMT">
#            <span class="herald-social-name">
#             Twitter
#            </span>
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-22">
#           <a href="https://instagram.com/">
#            <span class="herald-social-name">
#             Instagram
#            </span>
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <a class="herald-goto-top" href="javascript:void(0)" id="back-top">
#    <i class="fa fa-angle-up">
#    </i>
#   </a>
#   <script>
#    function loadScript(a){var b=document.getElementsByTagName("head")[0],c=document.createElement("script");c.type="text/javascript",c.src="https://tracker.metricool.com/app/resources/be.js",c.onreadystatechange=a,c.onload=a,b.appendChild(c)}loadScript(function(){beTracker.t({hash:'643aab579e9ab8680528be11e9e27f15'})})
#   </script>
#   <link href="https://www.sonoticias.com.br/wp-content/plugins/ml-slider/assets/sliders/flexslider/flexslider.css?ver=3.16.4" id="metaslider-flex-slider-css" media="all" property="stylesheet" rel="stylesheet" type="text/css"/>
#   <link href="https://www.sonoticias.com.br/wp-content/plugins/ml-slider/assets/metaslider/public.css?ver=3.16.4" id="metaslider-public-css" media="all" property="stylesheet" rel="stylesheet" type="text/css"/>
#   <style id="metaslider-public-inline-css" type="text/css">
#    .metaslider.metaslider-652661 .flexslider .flex-control-paging li a,
# 	.metaslider.metaslider-652661 .flexslider .flex-control-paging li a:hover {
# 		padding: 0;
# 		box-shadow: none;
# 		text-indent: -9999px;
# 		border-style: solid;
# 		display: inline-block;
# 		border-color: rgba(0,0,0,1);
# 		border-radius: 10px;
# 		-webkit-border-radius: 10px;
# 		-moz-border-radius: 10px;
# 		border-width: 0px;
# 		border: 0px solid rgba(0,0,0,1);
# 		line-height: 10px;
# 		width: 10px;
# 		height: 10px;
# 		margin: 0 4px;
# 		background: rgb(0,0,0);
# 		background: rgba(0,0,0,0.5);
# 		background: -webkit-gradient(linear, 0% 0%, 0% 100%, from(rgba(0,0,0,0.5)), to(rgba(0,0,0,0.5)));
# 		background: -webkit-linear-gradient(top, rgba(0,0,0,0.5), rgba(0,0,0,0.5));
# 		background: -moz-linear-gradient(top, rgba(0,0,0,0.5), rgba(0,0,0,0.5));
# 		background: -ms-linear-gradient(top, rgba(0,0,0,0.5), rgba(0,0,0,0.5));
# 		background: -o-linear-gradient(top, rgba(0,0,0,0.5), rgba(0,0,0,0.5));
# 		background: linear-gradient(top, rgba(0,0,0,0.5), rgba(0,0,0,0.5));
# 	}
#
# 	.metaslider.metaslider-652661 .flexslider .flex-control-paging li {
# 		margin: 0;
# 		text-indent: 0;
# 		width: auto;
# 	}
#
# 	.metaslider.metaslider-652661 .flexslider .flex-control-paging li a.flex-active {
# 		border: 0px solid rgba(0,0,0,1);
# 		background: rgb(0,0,0);
# 		background: rgba(0,0,0,1);
# 		background: -webkit-gradient(linear, 0% 0%, 0% 100%, from(rgba(0,0,0,1)), to(rgba(0,0,0,1)));
# 		background: -webkit-linear-gradient(top, rgba(0,0,0,1), rgba(0,0,0,1));
# 		background: -moz-linear-gradient(top, rgba(0,0,0,1), rgba(0,0,0,1));
# 		background: -ms-linear-gradient(top, rgba(0,0,0,1), rgba(0,0,0,1));
# 		background: -o-linear-gradient(top, rgba(0,0,0,1), rgba(0,0,0,1));
# 		background: linear-gradient(top, rgba(0,0,0,1), rgba(0,0,0,1));
# 	}
#
# 	.metaslider.metaslider-652661 .flexslider .flex-control-paging {
# 		line-height: 10px;
# 		z-index: 99;
# 		padding: 0;
# 		text-align: left;
# 		margin: 6px 0px;
# 		width: 100%;
# 		top: auto;
# 		right: auto;
# 		bottom: auto;
# 		left: auto;
# 		position: absolute;
# 		text-align: center;
# 	}
#
# 	.metaslider.metaslider-652661 .flexslider .caption-wrap {
# 		opacity: 1;
# 		margin: 0px 0px;
# 		color: rgb(255, 255, 255);
# 		background: rgb(0,0,0);
# 		background: rgba(0,0,0,0.7);
# 		width: 100%;
# 		top: auto;
# 		right: auto;
# 		bottom: 0;
# 		left: 0;
# 		clear: none;
# 		position: absolute;
# 		border-radius: 0px;
# 		-webkit-border-radius: 0px;
# 		-moz-border-radius: 0px;
# 	}
#
# 	.metaslider.metaslider-652661 .flexslider .flex-direction-nav .flex-prev {
# 		background: transparent url(https://www.sonoticias.com.br/wp-content/plugins/ml-slider-pro/modules/theme_editor/assets/arrows/white.png) 0 -498px no-repeat;
# 		margin-top: -17px;
# 		width: 34px;
# 		height: 34px;
# 		opacity: 0;
# 		left: 0px;
# 		padding: 0;
# 	}
#
# 	.metaslider.metaslider-652661 .flexslider .flex-direction-nav .flex-next {
# 		background: transparent url(https://www.sonoticias.com.br/wp-content/plugins/ml-slider-pro/modules/theme_editor/assets/arrows/white.png) 100% -498px no-repeat;
# 		margin-top: -17px;
# 		width: 34px;
# 		height: 34px;
# 		opacity: 0;
# 		right: 0px;
# 		padding: 0;
# 	}
#
# 	.metaslider.metaslider-652661 .flexslider:hover .flex-direction-nav .flex-prev {
# 		left: 5px;
# 		opacity: 0.7;
# 	}
#
# 	.metaslider.metaslider-652661 .flexslider:hover .flex-direction-nav .flex-next {
# 		right: 5px;
# 		opacity: 0.7;
# 	}
#
# 	.metaslider.metaslider-652661 {
# 		margin-bottom: 22px;
# 	}
#   </style>
#   <link href="https://www.sonoticias.com.br/wp-content/plugins/ml-slider-pro/assets/public.css?ver=2.16.0" id="metaslider-pro-public-css" media="all" property="stylesheet" rel="stylesheet" type="text/css"/>
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var wpcf7 = {"apiSettings":{"root":"https:\/\/www.sonoticias.com.br\/wp-json\/contact-form-7\/v1","namespace":"contact-form-7\/v1"}};
# /* ]]> */
#   </script>
#   <script src="https://www.sonoticias.com.br/wp-content/plugins/contact-form-7/includes/js/scripts.js?ver=5.1.7" type="text/javascript">
#   </script>
#   <script src="https://www.sonoticias.com.br/wp-includes/js/comment-reply.min.js?ver=4.9.14" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var herald_js_settings = {"ajax_url":"https:\/\/www.sonoticias.com.br\/wp-admin\/admin-ajax.php","rtl_mode":"false","header_sticky":"1","header_sticky_offset":"600","header_sticky_up":"","single_sticky_bar":"","popup_img":"1","logo":"https:\/\/www.sonoticias.com.br\/wp-content\/uploads\/2018\/06\/logo_sonoticias_branco.png","logo_retina":"https:\/\/www.sonoticias.com.br\/wp-content\/uploads\/2018\/06\/logo_sonoticias_branco@2x.png","logo_mini":"https:\/\/www.sonoticias.com.br\/wp-content\/uploads\/2018\/06\/logo_sonoticias_branco_peq.png","logo_mini_retina":"https:\/\/www.sonoticias.com.br\/wp-content\/uploads\/2018\/06\/logo_sonoticias_branco_peq@2x.png","smooth_scroll":"","trending_columns":"6","responsive_menu_more_link":"","header_ad_responsive":"","header_responsive_breakpoint":"1249"};
# /* ]]> */
#   </script>
#   <script src="https://www.sonoticias.com.br/wp-content/themes/herald/assets/js/min.js?ver=2.0" type="text/javascript">
#   </script>
#   <script src="https://www.sonoticias.com.br/wp-includes/js/wp-embed.min.js?ver=4.9.14" type="text/javascript">
#   </script>
#   <script src="https://www.sonoticias.com.br/wp-content/plugins/ml-slider/assets/sliders/flexslider/jquery.flexslider.min.js?ver=3.16.4" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var metaslider_652661 = function($) {
#             $('#metaslider_652661').flexslider({
#                 slideshowSpeed:3500,
#                 animation:"fade",
#                 controlNav:false,
#                 directionNav:true,
#                 pauseOnHover:true,
#                 direction:"horizontal",
#                 reverse:false,
#                 animationSpeed:600,
#                 prevText:"Anterior",
#                 nextText:"Próximo",
#                 fadeFirstSlide:false,
#                 slideshow:true
#             });
#             $(document).trigger('metaslider/initialized', '#metaslider_652661');
#         };
#         var timer_metaslider_652661 = function() {
#             var slider = !window.jQuery ? window.setTimeout(timer_metaslider_652661, 100) : !jQuery.isReady ? window.setTimeout(timer_metaslider_652661, 1) : metaslider_652661(window.jQuery);
#         };
#         timer_metaslider_652661();
#   </script>
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var milapfbwidgetvars = {"app_id":"125209568194468","select_lng":"pt_BR"};
# /* ]]> */
#   </script>
#   <script src="https://www.sonoticias.com.br/wp-content/plugins/facebook-pagelike-widget/fb.js?ver=1.0" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
secoes = page_soup.find_all("div", {"class": "herald-module"}) # Pega
noticias = {}
for i, secao in enumerate(secoes):
    h2 = secao.find('h2', {"class": "h6 herald-mod-h herald-color"})
    if h2:
        noticias[h2.text] = secao.find_all('article')

# %%
# Mostrar todas as notícias e os links delas
for key in noticias.keys():
    print("\n", key, "\n")
    for noticia in noticias[key]:
        print(f"{noticia.h2.text} -> {noticia.a['href']}")
# Out:
#  Polícia
#
# PRF apreende carga de cigarros contrabandeados em Sorriso -> https://www.sonoticias.com.br/category/policia/
# Homem é preso acusado de tráfico de drogas em Sorriso -> https://www.sonoticias.com.br/category/policia/
# Homem é preso por atirar em olho de gato com arma de pressão em Mato Grosso -> https://www.sonoticias.com.br/category/policia/
# Homem é socorrido após ser golpeado nas costas em Sinop; cunhado é suspeito -> https://www.sonoticias.com.br/category/policia/
# Dois são presos acusados de descumprirem ordem no bloqueio sanitário e desacatarem policiais em MT -> https://www.sonoticias.com.br/category/policia/
# Criminosos explodem caixa eletrônico e fogem com dinheiro em Mato Grosso -> https://www.sonoticias.com.br/category/policia/
# Governo de Mato Grosso inaugura Hospital Metropolitano com 238 leitos clínicos e 40 de UTI -> https://www.sonoticias.com.br/vimeo-video/governo-de-mato-grosso-inaugura-hospital-metropolitano-com-238-leitos-clinicos-e-40-de-uti/
# Unemat planeja retomada das aulas e oferta auxílios aos acadêmicos -> https://www.sonoticias.com.br/vimeo-video/unemat-planeja-retomada-das-aulas-e-oferta-auxilios-aos-academicos/
# Governo de Mato Grosso define ações de combate ao desmatamento ilegal -> https://www.sonoticias.com.br/vimeo-video/governo-de-mato-grosso-define-ac%cc%a7o%cc%83es-de-combate-ao-desmatamento-ilegal/
# Sinop Energia -> https://www.sonoticias.com.br/vimeo-video/sinop-energia-3/
# Secretária de Educação é favorável retomar aulas em Sinop -> https://www.sonoticias.com.br/vimeo-video/secretaria-de-educac%cc%a7a%cc%83o-e-favoravel-retomar-aulas-em-sinop/
# Polícia de Mato Grosso recebe mais armamentos -> https://www.sonoticias.com.br/vimeo-video/policia-de-mato-grosso-recebe-mais-armamentos/
#
#  Mais lidas
#
# Sorriso tem 40 casos de Coronavírus e secretaria constata foco de contaminação -> https://www.sonoticias.com.br/category/saude/
# Envolvidos em crimes trocam tiros com policiais no Nortão e são presos -> https://www.sonoticias.com.br/category/policia/
# Mais de 40 empresas são notificadas em Sinop por pessoas não usarem máscaras -> https://www.sonoticias.com.br/category/geral/
# Exército vai atuar em conjunto com operação em Mato Grosso para combater crimes ambientais -> https://www.sonoticias.com.br/category/politica/
# Mais duas pessoas morrem em Mato Grosso em decorrência do Coronavírus; total sobe para 26 -> https://www.sonoticias.com.br/category/saude/
# Mato Grosso registra 27ª morte por Coronavírus e 67 novos casos -> https://www.sonoticias.com.br/category/saude/
# Crise também impacta na construção do Shopping Sinop e instalação das lojas; inauguração é postergada -> https://www.sonoticias.com.br/category/economia/
# Mato Grosso tem 58 novos casos positivos de Coronavírus, 48 curados e duas mortes -> https://www.sonoticias.com.br/category/saude/
# Preso é violentamente espancado no presídio Ferrugem em Sinop -> https://www.sonoticias.com.br/category/policia/

# %%
def ver_secoes(noticias, return_last = False):
    if return_last:
        return return_last
    for i, key in enumerate(noticias.keys()):
        print(f"{i}: {key}")
    print(f"{i+1}: Sair")
    escolha = int(input("Escolha qual seção deseja ver: "))
    if escolha == i+1:
        return False
    secao = list(noticias.keys())[escolha]
    return secao

def ver_noticia(noticias, secao, Break = False):
    for i, noticia in enumerate(noticias[secao]):
        print(f"{i}: {noticia.h2.text}")
    print(f"{i+1}: Sair")
    escolha = int(input("Escolha qual notícia deseja ver: "))
    if escolha == i+1:
        return True
    noticia = noticias[secao][escolha].h2.a['href']
    webbrowser.open_new_tab(noticia)
    return False

return_last = False
while 1:
    try:
        secao = ver_secoes(noticias, return_last)
        clear_output()
        if not secao:
            break
        sair = ver_noticia(noticias, secao)
        clear_output()
        if sair:
            break
        print("0: Ler outra notícia")
        print("1: Voltar para secoes")
        print("2: Sair")
        escolha = int(input("Escolha uma ação: "))
        clear_output()
        
        if escolha == 0:
            return_last = secao
            continue
        elif escolha == 1:
            return_last = False
            continue
        else:
            break
        clear_output()
    except:
        print(f"Ocorreu um erro, tente novamente")
        break
